# %% [markdown]
# # Braindump
#
# ## Useful links
# https://dataspace.copernicus.eu/
#
# https://stacspec.org/en This is a standard used by a lot of providers
#
# https://planetarycomputer.microsoft.com/ Tutorial, data download, processing etc
#
# https://github.com/CDSETool/CDSETool Copernicus data tools also to use (other than microsoft stuff)
#
# https://xarray-spatial.readthedocs.io/en/stable/ Library to be used with geospacial data
#
#
# ## Thoughts
# I have written all the tools to be used in this project:
#
# two approaches: download tiles only once i get the dimention and everything else from eurocropsV2 and then save them in near enough data otherwise i might have a xarray that weights a lot, or to download using CDSEtools entire tiles preferably in ram, extract what i need and then save it, rinse and repeat to then finish creating the entire dataset. Beware that this will be a lot of data, so every possible optimization might be useful.
#
# Audentes Fortuna Iuvat
